# %%
import torch
from torch.utils.data import DataLoader
import numpy as np
import random
import sys
sys.path.append('/home/sw/Work5-SR/scripts/train')
from dataset import SubImageDataset

# %%
trainset = SubImageDataset(chunk_width=32, wflag=1)
trainloader = DataLoader(
    trainset,
    batch_size=32,
    shuffle=True,
    num_workers=4,  
)

X, Y = next(iter(trainloader))

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(8, 8, figsize=(16, 16))
for i in range(32):
    ax = axs[i*2//8, i*2%8]
    ax.imshow(X[i,0])
    ax.axis('off')
    ax = axs[i*2//8, i*2%8+1]
    ax.imshow(Y[i,0])
    ax.axis('off')
