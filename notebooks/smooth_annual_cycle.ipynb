# %%
import xarray as xr

# %%
ds_clim = xr.open_dataset("/home/sw/Work5-SR/dependency/stats/clim.CLDAS.pre.nc")

# %%
ds_clim
# Out:
# <xarray.Dataset>
# Dimensions:  (dayofyear: 366, lat: 1040, lon: 1600)
# Coordinates:
#   * lat      (lat) float32 0.03125 0.09375 0.1562 0.2188 ... 64.84 64.91 64.97
#   * lon      (lon) float32 60.03 60.09 60.16 60.22 ... 159.8 159.8 159.9 160.0
# Dimensions without coordinates: dayofyear
# Data variables:
#     pre      (dayofyear, lat, lon) float32 ...

# %%
ds_clim.isel(lat=648, lon=648).pre.plot()

# %%
ds_clim.isel(lat=555, lon=1000).pre.plot()

# %%
ds_clim = xr.open_dataset("/home/sw/Work5-SR/dependency/stats/clim.CLDAS.pre.smooth.nc")
ds_clim.isel(lat=648, lon=648).pre.plot()

# %%
from utils.nc_handler import smooth_annual_cycle

# %%
ds_clim_smooth = smooth_annual_cycle(ds_clim, 30)
ds_clim_smooth.isel(lat=648, lon=648).pre.plot()

# %%
ds_clim_smooth.isel(lat=555, lon=1000).pre.plot()

# %%
ds_clim_smooth = smooth_annual_cycle(ds_clim, 45)
ds_clim_smooth.isel(lat=648, lon=648).pre.plot()

# %%
ds_clim_smooth = smooth_annual_cycle(ds_clim, 60)
ds_clim_smooth.isel(lat=648, lon=648).pre.plot()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
idir = "/home/sw/Work5-SR/data/interim/DOY"
sdir = "/home/sw/Work5-SR/dependency/stats"
pname = "CLDAS"; var_name = "pre"
smooth_window = 31
import os
ds_clim_smooth = smooth_annual_cycle(ds_clim, 45)
ds_clim_smooth.to_netcdf(os.path.join(sdir, f"clim.{pname}.{var_name}.smooth.nc"))
